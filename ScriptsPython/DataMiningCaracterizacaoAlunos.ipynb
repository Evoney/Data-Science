# %%
import matplotlib.pyplot as plt
import pandas as pd
import pingouin as pg
import os
import seaborn as sns
# Out:
# /home/evoney/anaconda3/lib/python3.7/site-packages/distributed/utils.py:133: RuntimeWarning: Couldn't detect a suitable IP address for reaching '8.8.8.8', defaulting to '127.0.0.1': [Errno 101] Network is unreachable
#   RuntimeWarning,
# /home/evoney/anaconda3/lib/python3.7/site-packages/outdated/utils.py:18: OutdatedCheckFailedWarning: Failed to check for latest version of package.
# Set the environment variable OUTDATED_RAISE_EXCEPTION=1 for a full traceback.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   **kwargs

# %%
THIS_FILE_NAME = 'analise-correlação.py'
THIS_FILE_PATH = '/home/evoney/Documents/Pibic/' 


PLANILHA_carac_2018 = 'rawCaracterizacaoQPA-E.2018.csv'
PLANILHA_carac_2019 = 'rawCaracterizacaoQPA-E.2019.csv'

os.chdir(THIS_FILE_PATH)

df_carac_2018 = pd.read_csv(PLANILHA_carac_2018, sep=',')
df_carac_2019 = pd.read_csv(PLANILHA_carac_2019, sep=',')

# %%
df_carac_2018
df_carac_2019
# Out:
#                         Nome completo                Endereço de email  \
# 0                       melissa abreu   melissaabreu@icomp.ufam.edu.br
# 1                Diogo Abreu da Silva        diogo.abreu1992@gmail.com
# 2                        Euton Aguiar             eutonclash@gmail.com
# 3               Laura Aguiar Martinho       laura-martinho@hotmail.com
# 4                      Hellmut Albert          hellmutalbert@gmail.com
# ..                                ...                              ...
# 147      Emerson Veiga Monteiro FIlho  emerson.veiga@icomp.ufam.edu.br
# 148                       João victor       vitor_golden06@outlook.com
# 149  Renato Patrik Vinhote dos Santos        renatovinhote@hotmail.com
# 150                    paulo vinicius          paulobacelar8@gmail.com
# 151                     Igor Vinicius   igorvinicius@icomp.ufam.edu.br
#
#                             Data  \
# 0     quarta, 13 Mar 2019, 18:56
# 1     quarta, 13 Mar 2019, 10:35
# ...
